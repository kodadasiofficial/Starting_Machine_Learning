# %%
import numpy as np
import pandas as pd

# %%
m = np.random.randint(1,30,size = (5,3))
df = pd.DataFrame(m,columns = ["d1","d2","d3"])
df
# Out:
#    d1  d2  d3
# 0  16  25  15
# 1  23  20   5
# 2  22  15  19
# 3  10  20  24
# 4  23  24  23

# %%
df2 = df + 100

# %%
df2
# Out:
#     d1   d2   d3
# 0  116  125  115
# 1  123  120  105
# 2  122  115  119
# 3  110  120  124
# 4  123  124  123

# %%
pd.concat([df,df2],ignore_index = True)
# Out:
#     d1   d2   d3
# 0   16   25   15
# 1   23   20    5
# 2   22   15   19
# 3   10   20   24
# 4   23   24   23
# 5  116  125  115
# 6  123  120  105
# 7  122  115  119
# 8  110  120  124
# 9  123  124  123

# %%
df3 = pd.concat([df,df2],ignore_index = True,axis = 1)

# %%
# ?pd.concat

# %%
df3
# Out:
#     0   1   2    3    4    5
# 0  16  25  15  116  125  115
# 1  23  20   5  123  120  105
# 2  22  15  19  122  115  119
# 3  10  20  24  110  120  124
# 4  23  24  23  123  124  123

# %%
df3.columns = ["a1","a2","a3","a4","a5","a6"]

# %%
df3
# Out:
#    a1  a2  a3   a4   a5   a6
# 0  16  25  15  116  125  115
# 1  23  20   5  123  120  105
# 2  22  15  19  122  115  119
# 3  10  20  24  110  120  124
# 4  23  24  23  123  124  123

# %%
df2.columns = ["d1","d2","a1"]

# %%
pd.concat([df,df2],join = "inner")#sütun isimleri aynı olmayanları almaz
# Out:
#     d1   d2
# 0   16   25
# 1   23   20
# 2   22   15
# 3   10   20
# 4   23   24
# 0  116  125
# 1  123  120
# 2  122  115
# 3  110  120
# 4  123  124

# %%
pd.concat([df,df2],join_axes = [df.columns],ignore_index = True)#farklı isimli sütunlar varsa seçilen dataframedeki sütunları gösterir
# Out:
#     d1   d2    d3
# 0   16   25  15.0
# 1   23   20   5.0
# 2   22   15  19.0
# 3   10   20  24.0
# 4   23   24  23.0
# 5  116  125   NaN
# 6  123  120   NaN
# 7  122  115   NaN
# 8  110  120   NaN
# 9  123  124   NaN
